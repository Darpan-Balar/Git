# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sqlite3

# %%
import pandas as pd

certificates_earned = pd.DataFrame({
    'Certificates': [8, 2, 5, 6],
    'Time (in months)': [16, 5, 9, 12]
})

certificates_earned.index = ['Tom', 'Kris', 'Ahmad', 'Beau']

print(certificates_earned.iloc[3])
# Out:
# Certificates         6
# Time (in months)    12
# Name: Beau, dtype: int64

# %%
import pandas as pd
import numpy as np

s = pd.Series([np.nan, 1, 2, np.nan, 3])
s = s.fillna(method='ffill')

print(s)
# Out:
# 0    NaN
# 1    1.0
# 2    2.0
# 3    2.0
# 4    3.0
# dtype: float64

# %%
import pandas as pd
df = pd.read_csv('adult.data.csv')

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
df['overweight'] = (df['weight']*10000)/(df['height'] * df['height'])

# %%
df['overweight'] = df['overweight'] >25

# %%
df['overweight'] *= 1   # very important: to convert coloum values to 0 and 1s

# %%
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
# ...

# %%
df['cholesterol'] = df['cholesterol'] > 1
df['gluc'] = df['gluc'] > 1

# %%
df['gluc'] *= 1
df['cholesterol'] *= 1
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            0     0
# 1          1  20228       1     156    85.0    140     90            1     0
# 2          2  18857       1     165    64.0    130     70            1     0
# 3          3  17623       2     169    82.0    150    100            0     0
# 4          4  17474       1     156    56.0    100     60            0     0
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            0     0
# 69996  99995  22601       1     158   126.0    140     90            1     1
# 69997  99996  19066       2     183   105.0    180     90            1     0
# 69998  99998  22431       1     163    72.0    135     80            0     1
# 69999  99999  20540       1     170    72.0    120     80            1     0
#
# ...

# %%
df = df[df['ap_lo'] <= df['ap_hi']]

# %%
df = df[df['height'] >= df['height'].quantile(0.025)]

# %%
df = df[df['height'] <= df['height'].quantile(0.975)]
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            0     0
# 1          1  20228       1     156    85.0    140     90            1     0
# 2          2  18857       1     165    64.0    130     70            1     0
# 3          3  17623       2     169    82.0    150    100            0     0
# 4          4  17474       1     156    56.0    100     60            0     0
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69994  99992  21074       1     165    80.0    150     80            0     0
# 69995  99993  19240       2     168    76.0    120     80            0     0
# 69996  99995  22601       1     158   126.0    140     90            1     1
# 69998  99998  22431       1     163    72.0    135     80            0     1
# 69999  99999  20540       1     170    72.0    120     80            1     0
#
# ...

# %%
df = df[df['weight'] >= df['weight'].quantile(0.025)]
df = df[df['weight'] <= df['weight'].quantile(0.975)]
df
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            0     0
# 1          1  20228       1     156    85.0    140     90            1     0
# 2          2  18857       1     165    64.0    130     70            1     0
# 3          3  17623       2     169    82.0    150    100            0     0
# 4          4  17474       1     156    56.0    100     60            0     0
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69993  99991  19699       1     172    70.0    130     90            0     0
# 69994  99992  21074       1     165    80.0    150     80            0     0
# 69995  99993  19240       2     168    76.0    120     80            0     0
# 69998  99998  22431       1     163    72.0    135     80            0     1
# 69999  99999  20540       1     170    72.0    120     80            1     0
#
# ...

# %%
percentage_bachelors = (
    100*df['education'][df['education'] == 'Bachelors'].count())/df['education'].count()
percentage_bachelors
# Out:
# 16.446055096587944

# %%
deno = df['education'][df['salary'] == '>50K'].value_counts()
round(100 * (deno['Bachelors'] + deno['Masters'] + deno['Doctorate'])/deno.sum() ,1)
# Out:
# 44.5

# %%
import numpy as np

# %%
demo = df['occupation'][df['salary'] >= '>50K'][df['native-country']== 'India'].value_counts()
demo
# Out:
# Prof-specialty      25
# Exec-managerial      8
# Other-service        2
# Tech-support         2
# Transport-moving     1
# Sales                1
# Adm-clerical         1
# Name: occupation, dtype: int64

# %%
deno.sum()
